# %% [markdown]
# <a href="https://colab.research.google.com/github/Kensheretohelp/were-here-to-help-podcast-analytics/blob/main/TRIALMissingEpisodes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install playwright
# !playwright install chromium
# Out:
# Requirement already satisfied: playwright in /usr/local/lib/python3.12/dist-packages (1.56.0)
# Requirement already satisfied: pyee<14,>=13 in /usr/local/lib/python3.12/dist-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from pyee<14,>=13->playwright) (4.15.0)
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Please install them with the following command:      ║
# ║                                                      ║
# ║     playwright install-deps                          ║
# ║                                                      ║
# ║ Alternatively, use apt:                              ║
# ║     apt-get install libatk1.0-0\                     ║
# ║         libatk-bridge2.0-0\                          ║
# ║         libatspi2.0-0\                               ║
# ║         libxcomposite1                               ║
# ║                                                      ║
# ║ <3 Playwright Team                                   ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:961:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1083:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1072:7)
#     at async i.<anonymous> (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)

# %%
import os
import re
import json
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from openai import OpenAI

# ---------------------------------------------------------
# CONFIGURATION
# ---------------------------------------------------------

client = OpenAI(api_key="xxxxxxxxxxxx")   # or just OpenAI() if env var is set

HEADERS = {
    "User-Agent": "Mozilla/5.0 (WH2H Missing Episodes Scraper)",
    "Accept": "text/html",
}

REQUEST_SLEEP = 2


# ---------------------------------------------------------
# SAFE HTTP GET
# ---------------------------------------------------------
def safe_get(url, retries=5):
    for attempt in range(retries):
        try:
            r = requests.get(url, headers=HEADERS, timeout=25)
            if r.status_code == 200:
                return r.text
            else:
                print(f"  !! HTTP {r.status_code} at {url}")
        except Exception as e:
            print(f"  !! Request error: {e}")

        time.sleep(2 + attempt)

    print(f"  !! Failed after retries: {url}")
    return None


# ---------------------------------------------------------
# TRANSCRIPT EXTRACTOR (JSON → HTML FALLBACK)
# ---------------------------------------------------------
def extract_transcript(html):
    if not html:
        return None

    # ---- JSON transcript inside window.__INITIAL_STATE__
    m = re.search(r"window\.__INITIAL_STATE__\s*=\s*(\{.*?\})\s*;<", html, re.DOTALL)
    if m:
        try:
            state_json = json.loads(m.group(1))
        except:
            state_json = None

        transcription_url = None

        if state_json:
            # Primary JSON path
            try:
                transcription_url = state_json["pageData"]["episode"]["transcriptionUrl"]
            except:
                pass

            # Secondary JSON path
            if not transcription_url:
                try:
                    transcription_url = state_json["episode"]["transcriptionUrl"]
                except:
                    transcription_url = None

        # Fetch JSON transcript
        if transcription_url:
            if transcription_url.startswith("/"):
                transcription_url = "https://podscripts.co" + transcription_url

            tr = safe_get(transcription_url)
            if tr:
                try:
                    tr_json = json.loads(tr)
                    segments = (
                        tr_json.get("transcription", {}).get("segments")
                        or tr_json.get("segments")
                    )

                    if segments:
                        parts = [seg.get("text", "").strip() for seg in segments]
                        full = " ".join(parts)
                        full = re.sub(r"\s+", " ", full).strip()
                        if len(full) > 50:
                            return full
                except:
                    pass

    # ---- HTML fallback
    soup = BeautifulSoup(html, "html.parser")
    spans = soup.select("span.pod_text")
    if spans:
        txt = " ".join([s.get_text(" ", strip=True) for s in spans])
        txt = re.sub(r"\s+", " ", txt).strip()
        if len(txt) > 50:
            return txt

    return None


# ---------------------------------------------------------
# EXTRACT CALL SEGMENT (same as master script)
# ---------------------------------------------------------
def extract_call_segment(full_text, caller_obj, window=1200):
    if not full_text or not caller_obj:
        return None

    name = caller_obj.get("caller_name")
    if not name:
        return None

    # Case-insensitive search
    i = full_text.lower().find(name.lower())
    if i == -1:
        m = re.search(r"calling from", full_text, re.IGNORECASE)
        if not m:
            return None
        i = m.start()

    start = max(0, i - window)
    end = min(len(full_text), i + window)

    seg = full_text[start:end].strip()
    seg = re.sub(r"\s+", " ", seg)
    return seg


# ---------------------------------------------------------
# GPT CALLER EXTRACTION (JSON-COMPLIANT)
# ---------------------------------------------------------
def extract_callers_from_transcript(ep_num, transcript):
    if not transcript:
        return []

    prompt = f"""
You are analyzing a FULL transcript from the podcast "We're Here to Help".

The output must be valid JSON.

Your job: extract ONLY real phone callers.

Ignore:
- hosts (Jake, Gareth)
- guests
- characters/bits
- cold opens

Return ONLY this JSON structure:

{{
  "callers": [
    {{
      "caller_slot": 1,
      "caller_name": "FirstName",
      "caller_location": "City, State/Country or null",
      "reason_short": "short description"
    }}
  ]
}}

Rules:
- Use first names only.
- caller_slot must increment (1,2,3…)
- Skip unclear/non-callers.
- If no callers: return {{"callers": []}}

Transcript for episode {ep_num}:
\"\"\"{transcript}\"\"\"
"""

    for attempt in range(3):
        try:
            resp = client.chat.completions.create(
                model="gpt-4o-mini",
                response_format={"type": "json_object"},
                messages=[{"role": "user", "content": prompt}],
                temperature=0.1,
            )
            data = json.loads(resp.choices[0].message.content)
            callers = data.get("callers", [])
            if isinstance(callers, list):
                return callers
            return []
        except Exception as e:
            print(f"  !! GPT error (attempt {attempt+1}): {e}")
            time.sleep(2 + attempt)

    return []


# ---------------------------------------------------------
# MAIN — SCRAPE MISSING EPISODES
# ---------------------------------------------------------
def scrape_missing_episodes(
    rss_csv="episodes_master_clean.csv",
    links_csv="episode_links_manual.csv",
    output_csv="missing_episodes_scraped.csv"
):
    print("\nLoading episode metadata…")

    rss = pd.read_csv(rss_csv)
    rss["episode_number"] = pd.to_numeric(rss["episode_number"], errors="coerce")
    rss = rss.dropna(subset=["episode_number"]).copy()
    rss["episode_number"] = rss["episode_number"].astype(int)

    links = pd.read_csv(links_csv)
    links["episode_number"] = pd.to_numeric(links["episode_number"], errors="coerce")
    links = links.dropna(subset=["episode_number"]).copy()
    links["episode_number"] = links["episode_number"].astype(int)

    print("Merging RSS metadata with manual Podscripts links…")

    episodes = rss.merge(links, on="episode_number", how="inner")

    print(f"{len(episodes)} episodes ready to scrape.\n")

    all_rows = []

    for _, row in episodes.iterrows():
        ep = row["episode_number"]
        title = row["title"]
        url = row["correct_url"]

        print(f"\n=== Episode {ep}: {title} ===")
        print("URL:", url)

        html = safe_get(url)
        transcript = extract_transcript(html)

        if transcript:
            print(f"  Transcript length: {len(transcript)} chars")
        else:
            print("  !! No transcript extracted.")

        callers = extract_callers_from_transcript(ep, transcript)
        print(f"  → Callers found: {len(callers)}")

        if not callers:
            all_rows.append({
                "episode_num": ep,
                "episode_title_raw": title,
                "episode_url": url,
                "caller_slot": None,
                "caller_name": None,
                "caller_location": None,
                "reason_short": None,
                "call_segment": None
            })
        else:
            for c in callers:
                seg = extract_call_segment(transcript, c)
                all_rows.append({
                    "episode_num": ep,
                    "episode_title_raw": title,
                    "episode_url": url,
                    "caller_slot": c.get("caller_slot"),
                    "caller_name": c.get("caller_name"),
                    "caller_location": c.get("caller_location"),
                    "reason_short": c.get("reason_short"),
                    "call_segment": seg
                })

        time.sleep(REQUEST_SLEEP)

    df = pd.DataFrame(all_rows)
    df.to_csv(output_csv, index=False)

    print("\nSaved →", output_csv)
    return df


# ---------------------------------------------------------
# RUN
# ---------------------------------------------------------
scrape_missing_episodes()
# Out:
# Loading episode metadata…
# Merging RSS metadata with manual Podscripts links…
# 50 episodes ready to scrape.
#
#
# === Episode 215: 215: BEST ADVICE Vol 2: Make It Your Own (with Cat Reitman) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/215-best-advice-vol-2-make-it-your-own-with-cat-reitman?scroll_to_words=215&search_type=basic
#   Transcript length: 48776 chars
#   → Callers found: 3
#
# === Episode 214: 214: Too Wholesome for Doggy & Ethiopian Jazz ===
# URL: https://podscripts.co/podcasts/were-here-to-help/214-too-wholesome-for-doggy-ethiopian-jazz?scroll_to_words=214&search_type=basic
#   Transcript length: 62136 chars
#   → Callers found: 3
#
# === Episode 213: 213: Trash Hole Shark & Wrestling Gators (with Andy Roddick) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/213-trash-hole-shark-wrestling-gators-with-andy-roddick?scroll_to_words=213&search_type=basic
#   Transcript length: 59574 chars
#   → Callers found: 2
#
# === Episode 212: 212: Sh*t Show & The Fancy Dorris Football League ===
# URL: https://podscripts.co/podcasts/were-here-to-help/212-sht-show-the-fancy-dorris-football-league?scroll_to_words=212&search_type=basic
#   Transcript length: 55899 chars
#   → Callers found: 2
#
# === Episode 211: 211: WEIRD Here to Help: Angry Old Hitchhiker & A Two-Time Hat Thief ===
# URL: https://podscripts.co/podcasts/were-here-to-help/211-weird-here-to-help-vol-1-angry-old-hitchhiker-a-two-time-hat-thief-with-steve-berg-and-eric-edelstein?scroll_to_words=211&search_type=basic
#   Transcript length: 58481 chars
#   → Callers found: 2
#
# === Episode 210: 210: A Ship-Load of Options (with Cat Reitman) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/210-a-ship-load-of-options-with-cat-reitman?scroll_to_words=210&search_type=basic
#   Transcript length: 73799 chars
#   → Callers found: 3
#
# === Episode 209: 209: Very Important Pickles & Twenty-Second Pilot ===
# URL: https://podscripts.co/podcasts/were-here-to-help/209-very-important-pickles-twenty-second-pilot?scroll_to_words=209&search_type=basic
#   Transcript length: 68482 chars
#   → Callers found: 2
#
# === Episode 208: 208: BEST ADVICE Vol 1: Bare Bowling It ===
# URL: https://podscripts.co/podcasts/were-here-to-help/208-best-advice-vol-1-bare-bowling-it?scroll_to_words=208&search_type=basic
#   Transcript length: 47720 chars
#   → Callers found: 6
#
# === Episode 207: 207: Laughing Emoji Laughing Emoji Laughing Emoji ===
# URL: https://podscripts.co/podcasts/were-here-to-help/207-laughing-emoji-laughing-emoji-laughing-emoji?scroll_to_words=207&search_type=basic
#   Transcript length: 57824 chars
#   → Callers found: 2
#
# === Episode 206: 206: CHAT Vol 4: Light and Love ===
# URL: https://podscripts.co/podcasts/were-here-to-help/206-were-here-to-chat-vol-4-light-and-love-with-steve-berg-and-eric-edelstein?scroll_to_words=206&search_type=basic
#   Transcript length: 62594 chars
#   → Callers found: 0
#
# === Episode 205: 205: Find Your Switzer & Like a Prayer ===
# URL: https://podscripts.co/podcasts/were-here-to-help/205-find-your-switzer-like-a-prayer?scroll_to_words=205&search_type=basic
#   Transcript length: 76463 chars
#   → Callers found: 3
#
# === Episode 204: 204: 50mg of Nuge & Phish Burial (with Pelle Almqvist) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/204-50mg-of-nuge-phish-burial-with-pelle-almqvist?scroll_to_words=204&search_type=basic
#   Transcript length: 51224 chars
#   → Callers found: 3
#
# === Episode 203: 203: Lotta Cheese in London & Selling a Lemon ===
# URL: https://podscripts.co/podcasts/were-here-to-help/203-lotta-cheese-in-london-selling-a-lemon?scroll_to_words=203&search_type=basic
#   Transcript length: 86635 chars
#   → Callers found: 3
#
# === Episode 202: 202: The Friendship Game Casting Special: I Have a Connection ===
# URL: https://podscripts.co/podcasts/were-here-to-help/202-the-friendship-game-casting-special-i-have-a-connection?scroll_to_words=202&search_type=basic
#   Transcript length: 56146 chars
#   → Callers found: 6
#
# === Episode 201: 201: The Pickle and Chip Classic & CopperTone Style (with Beck Bennett) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/201-the-pickle-and-chip-classic-coppertone-style-with-beck-bennett?scroll_to_words=201&search_type=basic
#   Transcript length: 81760 chars
#   → Callers found: 3
#
# === Episode 200: 200: 200th Episode Special: Two Hams and a Cave & Sisterhood of the Traveling Vest ===
# URL: https://podscripts.co/podcasts/were-here-to-help/200-200th-episode-special-two-hams-and-a-cave-sisterhood-of-the-traveling-vest?scroll_to_words=200&search_type=basic
#   Transcript length: 76339 chars
#   → Callers found: 10
#
# === Episode 199: 199: CHAT Vol. 3: Good Goofy Fun ===
# URL: https://podscripts.co/podcasts/were-here-to-help/199-were-here-to-chat-vol-3-good-goofy-fun-with-steve-berg-and-eric-edelstein?scroll_to_words=199&search_type=basic
#   Transcript length: 65554 chars
#   → Callers found: 1
#
# === Episode 198: 198: Masterclass & Water Wubbie ===
# URL: https://podscripts.co/podcasts/were-here-to-help/198-masterclass-water-wubbie?scroll_to_words=198&search_type=basic
#   Transcript length: 69091 chars
#   → Callers found: 3
#
# === Episode 197: 197: Dog Communication & Don't Cry For Me, Season Tickets (with Judd Apatow) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/197-dog-communication-dont-cry-for-me-season-tickets-with-judd-apatow?scroll_to_words=197&search_type=basic
#   Transcript length: 60990 chars
#   → Callers found: 2
#
# === Episode 196: 196: Mannequin For Dennehy & A Party For Adults ===
# URL: https://podscripts.co/podcasts/were-here-to-help/196-mannequin-for-dennehy-a-party-for-adults?scroll_to_words=196&search_type=basic
#   Transcript length: 76559 chars
#   → Callers found: 4
#
# === Episode 195: 195: It’s a Parade & Monopoly Intervention (with Ty Burrell) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/195-its-a-parade-monopoly-intervention-with-ty-burrell?scroll_to_words=195&search_type=basic
#   Transcript length: 58282 chars
#   → Callers found: 2
#
# === Episode 194: 194: Bucket of Frogs & Some Guy Named Roy ===
# URL: https://podscripts.co/podcasts/were-here-to-help/194-bucket-of-frogs-some-guy-named-roy?scroll_to_words=194&search_type=basic
#   Transcript length: 62381 chars
#   → Callers found: 3
#
# === Episode 193: 193: Baby Face in the Delta Lounge & The Goodnight Show (with Roy Wood Jr.) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/193-baby-face-in-the-delta-lounge-the-goodnight-show-with-roy-wood-jr?scroll_to_words=193&search_type=basic
#   Transcript length: 67292 chars
#   → Callers found: 3
#
# === Episode 192: 192: Jump at the Chance & The Death of Gaia Moondancer ===
# URL: https://podscripts.co/podcasts/were-here-to-help/192-jump-at-the-chance-the-death-of-gaia-moondancer?scroll_to_words=192&search_type=basic
#   Transcript length: 60669 chars
#   → Callers found: 3
#
# === Episode 191: 191: CHAT Vol. 2: Ghost Ebay ===
# URL: https://podscripts.co/podcasts/were-here-to-help/191-were-here-to-chat-vol-2-ghost-ebay-with-steve-berg-and-eric-edelstein?scroll_to_words=191&search_type=basic
#   Transcript length: 65902 chars
#   → Callers found: 0
#
# === Episode 190: 190: Box of Cigars and A Bottle of Whiskey & Reverse Benjamin Button ===
# URL: https://podscripts.co/podcasts/were-here-to-help/190-box-of-cigars-and-a-bottle-of-whiskey-reverse-benjamin-button?scroll_to_words=190&search_type=basic
#   Transcript length: 58121 chars
#   → Callers found: 3
#
# === Episode 189: 189: Let's Get Outta the Garage Together ===
# URL: https://podscripts.co/podcasts/were-here-to-help/189-lets-get-outta-the-garage-together?scroll_to_words=189&search_type=basic
#   Transcript length: 87453 chars
#   → Callers found: 3
#
# === Episode 188: 188: Digging Up Orville & Quiznos Bag ===
# URL: https://podscripts.co/podcasts/were-here-to-help/188-digging-up-orville-quiznos-bag?scroll_to_words=188&search_type=basic
#   Transcript length: 73493 chars
#   → Callers found: 3
#
# === Episode 187: 187: The Man in the Iron Hair & The Oprah of Lube (with Justin Long) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/187-the-man-in-the-iron-hair-the-oprah-of-lube-with-justin-long?scroll_to_words=187&search_type=basic
#   Transcript length: 67348 chars
#   → Callers found: 3
#
# === Episode 186: 186: I Ask the Questions & I Love My Wife ===
# URL: https://podscripts.co/podcasts/were-here-to-help/186-i-ask-the-questions-i-love-my-wife?scroll_to_words=186&search_type=basic
#   Transcript length: 80386 chars
#   → Callers found: 2
#
# === Episode 185: 185: CHAT Vol. 1: Good Bit Man, Let's Go ===
# URL: https://podscripts.co/podcasts/were-here-to-help/185-good-bit-man-lets-go-with-steve-berg-and-eric-edelstein?scroll_to_words=185&search_type=basic
#   Transcript length: 58327 chars
#   → Callers found: 0
#
# === Episode 184: 184: A Classic Vinnie Problem & Guest Host Energy ===
# URL: https://podscripts.co/podcasts/were-here-to-help/184-a-classic-vinnie-problem-guest-host-energy?scroll_to_words=184&search_type=basic
#   Transcript length: 66962 chars
#   → Callers found: 2
#
# === Episode 183: 183: RE-RELEASE: Jake's Faves: This Show's Becoming Jackass ===
# URL: https://podscripts.co/podcasts/were-here-to-help/183-jakes-faves-this-shows-becoming-jackass-re-release?scroll_to_words=183&search_type=basic
#   Transcript length: 68489 chars
#   → Callers found: 2
#
# === Episode 182: 182: The Freshmaker! & Now This B Is Taking Pics ===
# URL: https://podscripts.co/podcasts/were-here-to-help/182-the-freshmaker-now-this-b-is-taking-pics?scroll_to_words=182&search_type=basic
#   Transcript length: 75628 chars
#   → Callers found: 3
#
# === Episode 181: 181: All in Crumbles (with Steve Berg) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/181-all-in-crumbles-with-steve-berg?scroll_to_words=181&search_type=basic
#   Transcript length: 62263 chars
#   → Callers found: 2
#
# === Episode 180: 180: Hotdog Party & Backdoor Boys ===
# URL: https://podscripts.co/podcasts/were-here-to-help/180-hotdog-party-backdoor-boys?scroll_to_words=180&search_type=basic
#   Transcript length: 74416 chars
#   → Callers found: 3
#
# === Episode 179: 179: RE-RELEASE: Gareth's Faves: Nothing But Cats ===
# URL: https://podscripts.co/podcasts/were-here-to-help/179-gareths-faves-nothing-but-cats-re-release?scroll_to_words=179&search_type=basic
#   Transcript length: 53917 chars
#   → Callers found: 3
#
# === Episode 178: 178: Add a Zero & Boys Supporting Boys ===
# URL: https://podscripts.co/podcasts/were-here-to-help/178-add-a-zero-boys-supporting-boys?scroll_to_words=178&search_type=basic
#   Transcript length: 71921 chars
#   → Callers found: 2
#
# === Episode 177: 177: Duo Ling-Crow & You Got Nudes (with Nick Kroll) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/177-duo-ling-crow-you-got-nudes-with-nick-kroll?scroll_to_words=177&search_type=basic
#   Transcript length: 86794 chars
#   → Callers found: 2
#
# === Episode 176: 176: Samples & Raised by Elves ===
# URL: https://podscripts.co/podcasts/were-here-to-help/176-samples-raised-by-elves?scroll_to_words=176&search_type=basic
#   Transcript length: 62502 chars
#   → Callers found: 3
#
# === Episode 175: 175: A Thing For Dinosaurs (with Derek Waters and Zach Shields) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/175-a-thing-for-dinosaurs-with-derek-waters-and-zach-shields?scroll_to_words=175&search_type=basic
#   Transcript length: 66403 chars
#   → Callers found: 4
#
# === Episode 174: 174: Sucking a Bald Spot & Tree Jim ===
# URL: https://podscripts.co/podcasts/were-here-to-help/174-sucking-a-bald-spot-tree-jim?scroll_to_words=174&search_type=basic
#   Transcript length: 76197 chars
#   → Callers found: 3
#
# === Episode 173: 173: Boyfriend Doodies & Pro Boner Advice (with Jameela Jamil) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/173-boyfriend-doodies-pro-boner-advice-with-jameela-jamil?scroll_to_words=173&search_type=basic
#   Transcript length: 61954 chars
#   → Callers found: 2
#
# === Episode 172: 172: Babe on Men & Do It For Thailand ===
# URL: https://podscripts.co/podcasts/were-here-to-help/172-babe-on-men-do-it-for-thailand?scroll_to_words=172&search_type=basic
#   Transcript length: 71537 chars
#   → Callers found: 3
#
# === Episode 171: 171: Walk This Lonely Dream & Shake Your Little Butts (with Jillian Bell) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/171-walk-this-lonely-dream-shake-your-little-butts-with-jillian-bell?scroll_to_words=171&search_type=basic
#   Transcript length: 62927 chars
#   → Callers found: 2
#
# === Episode 170: 170: Occasional Blue Jays & Butt Grazing ===
# URL: https://podscripts.co/podcasts/were-here-to-help/170-occasional-blue-jays-butt-grazing?scroll_to_words=170&search_type=basic
#   Transcript length: 76275 chars
#   → Callers found: 3
#
# === Episode 169: 169: A Horse in a Dog's Body & So Much Utah (with Chloe Fineman) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/169-a-horse-in-a-dogs-body-so-much-utah-with-chloe-fineman?scroll_to_words=169&search_type=basic
#   Transcript length: 66798 chars
#   → Callers found: 2
#
# === Episode 168: 168: I Feel Barfy & An I Love You, Man Situation ===
# URL: https://podscripts.co/podcasts/were-here-to-help/168-i-feel-barfy-an-i-love-you-man-situation?scroll_to_words=168&search_type=basic
#   Transcript length: 69967 chars
#   → Callers found: 4
#
# === Episode 167: 167: RE-RELEASE: Fan Faves: Chronicles of Conor ===
# URL: https://podscripts.co/podcasts/were-here-to-help/167-the-peoples-picks-chronicles-of-conor-re-release?scroll_to_words=167&search_type=basic
#   Transcript length: 90213 chars
#   → Callers found: 2
#
# === Episode 166: 166: No Shoes, No Shirt, Teeth In & Unwrapping Whoppers (with Steve Berg) ===
# URL: https://podscripts.co/podcasts/were-here-to-help/166-no-shoes-no-shirt-teeth-in-unwrapping-whoppers-with-steve-berg?scroll_to_words=166&search_type=basic
#   Transcript length: 90501 chars
#   → Callers found: 2
#
# Saved → missing_episodes_scraped.csv
#      episode_num                                  episode_title_raw  \
# 0            215  215: BEST ADVICE Vol 2: Make It Your Own (with...
# 1            215  215: BEST ADVICE Vol 2: Make It Your Own (with...
# 2            215  215: BEST ADVICE Vol 2: Make It Your Own (with...
# 3            214      214: Too Wholesome for Doggy & Ethiopian Jazz
# 4            214      214: Too Wholesome for Doggy & Ethiopian Jazz
# ..           ...                                                ...
# 135          168   168: I Feel Barfy & An I Love You, Man Situation
# 136          167    167: RE-RELEASE: Fan Faves: Chronicles of Conor
# 137          167    167: RE-RELEASE: Fan Faves: Chronicles of Conor
# 138          166  166: No Shoes, No Shirt, Teeth In & Unwrapping...
# 139          166  166: No Shoes, No Shirt, Teeth In & Unwrapping...
#
#                                            episode_url  caller_slot  \
# 0    https://podscripts.co/podcasts/were-here-to-he...          1.0
# 1    https://podscripts.co/podcasts/were-here-to-he...          2.0
# 2    https://podscripts.co/podcasts/were-here-to-he...          3.0
# 3    https://podscripts.co/podcasts/were-here-to-he...          1.0
# 4    https://podscripts.co/podcasts/were-here-to-he...          2.0
# ..                                                 ...          ...
# 135  https://podscripts.co/podcasts/were-here-to-he...          4.0
# 136  https://podscripts.co/podcasts/were-here-to-he...          1.0
# 137  https://podscripts.co/podcasts/were-here-to-he...          2.0
# 138  https://podscripts.co/podcasts/were-here-to-he...          1.0
# 139  https://podscripts.co/podcasts/were-here-to-he...          2.0
#
#     caller_name          caller_location  \
# 0       Whitney                     null
# 1         Katie  Raleigh, North Carolina
# 2        Sophie                     null
# 3        Jordan                  Florida
# 4        Ashley                San Diego
# ..          ...                      ...
# 135       Stone        Stanton, Virginia
# 136      Connor             Florida, USA
# 137       Carly            New York, USA
# 138       Tammy               California
# 139        Jeff              Chicago, IL
#
#                                           reason_short  \
# 0    Struggled with the consistency of oatmeal and ...
# 1    Used advice from the show to make flossing fun...
# 2    Had two job offers and received advice to ask ...
# 3      Friend wants a Disney tattoo over a tramp stamp
# 4       Trying to avoid a timeshare sales presentation
# ..                                                 ...
# 135     Discussing perceptions of having a foot fetish
# 136  Living with senior roommates and dealing with ...
# 137  Father refuses to use air conditioning in hot ...
# 138                  Employee stopped wearing dentures
# 139                              Bathroom trough issue
#
#                                           call_segment
# 0    Kings, Steve and Eric. The best moment from th...
# 1    ause it was so precarious. Make it your own. T...
# 2    morning. And I remember we went to a bar close...
# 3    ot to tell her. And then the caller was like, ...
# 4    hem know that we sent you after checkout. Lisa...
# ..                                                 ...
# 135  d free way to support the podcast. Take you tw...
# 136  me markets for a limited time only. Calling al...
# 137  n you're hot You could say like hey, man. Do y...
# 138  ah, blah, blah, blah. Oh, cool, okay. Well, yo...
# 139  65 day returns quince.com slash here to help. ...
#
# [140 rows x 8 columns]
